# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from io import StringIO
import csv

filepath = 'C:/Users/andre/.ipynb_checkpoints/'

#with open(filepath + 'google_dataset.csv', encoding="utf8") as f:
#    file = StringIO(f.read().replace('\\','\\"'))
#    f = f.write(file)


#reader = csv.reader(open(filepath + 'facebook_dataset.csv', encoding="utf8")) 
#lines = list(reader)
#for line in lines:
#    for s in line:
#        s = s.replace('\n"', "\n|").replace('"\n', '|\n')
#        s = s.replace('",', '|,').replace(',"', ',|')
#        s = s.replace('"', "")
#       s = s.replace('|', '"')
        
#writer = csv.writer(open(filepath + 'new_facebook_dataset.csv', 'w', encoding="utf8"))
#writer.writerows(lines)
        
#with open(filepath + 'new1_google_dataset.csv', encoding="utf8") as csvfile:
#    reader = csv.reader(csvfile)
#   for row in reader:
#        corrected = []
#        for cell in row:
#            corrected.append(cell.replace('\\', ' ')) # Gross! See below.
#        writer.writerow(corrected)
    

#import requests

#with open(filepath + 'facebook_dataset.csv', encoding="utf8") as csvfile1:
#    dialect1 = csv.Sniffer().sniff(csvfile1.read())
#with open(filepath + 'google_dataset.csv', encoding="utf8") as csvfile2:
#    dialect2 = csv.Sniffer().sniff(csvfile2.read())
#with open(filepath + 'website_dataset.csv', encoding="utf8") as csvfile3:
#    dialect3 = csv.Sniffer().sniff(csvfile3.read())


df1 = pd.read_csv(filepath + 'new_facebook_dataset.csv',  sep=',', on_bad_lines='warn')
df2 = pd.read_csv(filepath + 'google_dataset.csv',  sep=',', on_bad_lines='warn')
df3 = pd.read_csv(filepath + 'website_dataset.csv', sep=';', on_bad_lines='warn')
# Out:
# b'Skipping line 871: expected 16 fields, saw 24\nSkipping line 929: expected 16 fields, saw 23\nSkipping line 1067: expected 16 fields, saw 24\nSkipping line 1093: expected 16 fields, saw 24\nSkipping line 1137: expected 16 fields, saw 19\nSkipping line 1355: expected 16 fields, saw 20\nSkipping line 1429: expected 16 fields, saw 22\nSkipping line 1531: expected 16 fields, saw 78\nSkipping line 1565: expected 16 fields, saw 32\nSkipping line 1817: expected 16 fields, saw 20\nSkipping line 1995: expected 16 fields, saw 25\nSkipping line 2193: expected 16 fields, saw 20\nSkipping line 2381: expected 16 fields, saw 17\nSkipping line 2525: expected 16 fields, saw 18\nSkipping line 2633: expected 16 fields, saw 20\nSkipping line 2641: expected 16 fields, saw 30\nSkipping line 2811: expected 16 fields, saw 28\nSkipping line 2825: expected 16 fields, saw 22\nSkipping line 2845: expected 16 fields, saw 46\nSkipping line 3709: expected 16 fields, saw 20\nSkipping line 3925: expected 16 fields
# ...

# %%
df1.shape
# Out:
# (71169, 16)

# %%
df2.shape
# Out:
# (346926, 15)

# %%
df3.shape
# Out:
# (72018, 11)

# %%
df2.dtypes
# Out:
# address               object
# category              object
# city                  object
# country_code          object
# country_name          object
# name                  object
# phone                 object
# phone_country_code    object
# raw_address           object
# raw_phone             object
# region_code           object
# region_name           object
# text                  object
# zip_code              object
# domain                object
# dtype: object

# %%
df1.nunique()
# Out:
# domain                71169
# address               56438
# categories            10074
# city                   6326
# country_code            130
# country_name            116
# description           26813
# email                 19746
# link                  71169
# name                  71001
# page_type                 4
# phone                 44272
# phone_country_code      100
# region_code             434
# region_name             681
# zip_code              25958
# dtype: int64

# %%
df2.nunique()
# Out:
# address               274699
# category                 469
# city                   22066
# country_code             213
# country_name             187
# name                  344400
# phone                 286113
# phone_country_code       212
# raw_address           137702
# raw_phone             284781
# region_code              678
# region_name             1502
# text                  339461
# zip_code              100698
# domain                 70109
# dtype: int64

# %%
df3.nunique()
# Out:
# root_domain      72017
# domain_suffix      667
# language            71
# legal_name       30619
# main_city         9598
# main_country       294
# main_region       1114
# phone            60053
# site_name        67541
# tld                293
# s_category         562
# dtype: int64

# %%
df1.head()
# Out:
#                     domain                                            address  \
# 0       euro-hygiene-34.fr  134 rue entrepreneurs, za du vigné, 30420, cal...
# 1  lakesidehomeservices.ca                                                NaN
# 2        rossiterboats.com                                                NaN
# 3     caa-architecture.com  601 cordova st w # 270, v6b 1g1, vancouver, bc...
# 4            apexsurety.ca  unit 3 - 4 donald street, r3l 2t7, winnipeg, m...
#
#                                           categories       city country_code  \
# 0                                                NaN  calvisson           fr
# 1  Appliance Repair & Maintenance|Home Builders &...        NaN           ca
# 2        Boats & Yachts Dealers|Boat Tours & Cruises        NaN          NaN
# 3  Architects & Architectural Services|Other Engi...  vancouver           ca
# 4                                                NaN   winnipeg           ca
#
# ...

# %%
df1 = df1.drop(['country_code','description','email','link','page_type','phone_country_code','region_code'], axis=1)
df1.rename(columns={'categories':'category','country_name':'country','region_name':'region'}, inplace=True)
df1.head()
# Out:
#                     domain                                            address  \
# 0       euro-hygiene-34.fr  134 rue entrepreneurs, za du vigné, 30420, cal...
# 1  lakesidehomeservices.ca                                                NaN
# 2        rossiterboats.com                                                NaN
# 3     caa-architecture.com  601 cordova st w # 270, v6b 1g1, vancouver, bc...
# 4            apexsurety.ca  unit 3 - 4 donald street, r3l 2t7, winnipeg, m...
#
#                                             category       city country  \
# 0                                                NaN  calvisson  france
# 1  Appliance Repair & Maintenance|Home Builders &...        NaN     NaN
# 2        Boats & Yachts Dealers|Boat Tours & Cruises        NaN     NaN
# 3  Architects & Architectural Services|Other Engi...  vancouver  canada
# 4                                                NaN   winnipeg  canada
#
# ...

# %%
df2.head()
# Out:
#                                              address  \
# 0  28 Central Coast Hwy, West Gosford NSW 2250, A...
# 1   400 Scott St, St. Catharines, ON L2M 3W2, Canada
# 2      191 Pleasant St, Yarmouth, NS B5A 2J9, Canada
# 3  11040 Santa Monica Blvd Suite 370, Los Angeles...
# 4                                                NaN
#
#                             category            city country_code  \
# 0            Fabric-Based Home Goods         gosford           au
# 1                        Book Stores  st. catharines           ca
# 2  Other Building Material Retailers        yarmouth           ca
# 3            Plastic Surgery Clinics     los angeles           us
# 4                Catering & Delivery             NaN          NaN
#
#     country_name                                name         phone  \
# 0      australia              Spotlight West Gosford  +61243355946
# 1         canada       Heritage Christian Book Store  +19059374553
# ...

# %%
df2 = df2.drop(['country_code','raw_address','raw_phone','text','phone_country_code','region_code'], axis=1)
df2.rename(columns={'country_name':'country','region_name':'region'}, inplace=True)
df2.head()
# Out:
#                                              address  \
# 0  28 Central Coast Hwy, West Gosford NSW 2250, A...
# 1   400 Scott St, St. Catharines, ON L2M 3W2, Canada
# 2      191 Pleasant St, Yarmouth, NS B5A 2J9, Canada
# 3  11040 Santa Monica Blvd Suite 370, Los Angeles...
# 4                                                NaN
#
#                             category            city        country  \
# 0            Fabric-Based Home Goods         gosford      australia
# 1                        Book Stores  st. catharines         canada
# 2  Other Building Material Retailers        yarmouth         canada
# 3            Plastic Surgery Clinics     los angeles  united states
# 4                Catering & Delivery             NaN            NaN
#
#                                  name         phone           region zip_code  \
# 0              Spotlight West Gosford  +61243355946  new south wales     2250
# ...

# %%
df3.head()
# Out:
#            root_domain domain_suffix language  \
# 0     converterman.com           NaN      NaN
# 1  clothesencounter.ca            ca       en
# 2       investa.com.au        com.au       en
# 3    timminsgarage.com           com       en
# 4         destinate.ca            ca       en
#
#                                    legal_name main_city main_country  \
# 0                                         NaN       NaN          NaN
# 1                                         NaN  cardigan       canada
# 2  Investa Wholesale Funds Management Limited  brisbane    australia
# 3                         Timmins Garage Inc.   timmins       canada
# 4                        Destinate Group Ltd.       NaN       Canada
#
#             main_region        phone               site_name  tld  \
# 0                   NaN          NaN                     NaN  NaN
# 1  prince edward island  13066937766       Clothes Encounter   ca
# 2            queensland  61282269300  Investa Property Group   au
# ...

# %%
df3 = df3.drop(['domain_suffix','language','legal_name','tld'], axis=1)
df3.rename(columns={'root_domain': 'domain','main_city': 'city', 'main_country': 'country', 'main_region': 'region', 'site_name': 'name', 's_category': 'category'}, inplace=True)
df3.head()
# Out:
#                 domain      city    country                region  \
# 0     converterman.com       NaN        NaN                   NaN
# 1  clothesencounter.ca  cardigan     canada  prince edward island
# 2       investa.com.au  brisbane  australia            queensland
# 3    timminsgarage.com   timmins     canada               ontario
# 4         destinate.ca       NaN     Canada                   NaN
#
#          phone                    name                            category
# 0          NaN                     NaN                                 NaN
# 1  13066937766       Clothes Encounter       Shoes & Other Footwear Stores
# 2  61282269300  Investa Property Group              Real Estate Developers
# 3  18775896640          Timmins Garage  Automobile Dealers & Manufacturers
# 4          NaN         Destinate Group                 Business Consulting

# %%
df1 = df1.astype({'phone':'string'})

# %%
df2.merge(df1, on=['domain','name','category','address','city','region','country','zip_code','phone'], how='left')
# Out:
#                                                   address  \
# 0       28 Central Coast Hwy, West Gosford NSW 2250, A...
# 1        400 Scott St, St. Catharines, ON L2M 3W2, Canada
# 2           191 Pleasant St, Yarmouth, NS B5A 2J9, Canada
# 3       11040 Santa Monica Blvd Suite 370, Los Angeles...
# 4                                                     NaN
# ...                                                   ...
# 346921  12b Marsh Cl, Winterbourne, Bristol BS36 1HY, ...
# 346922                                                NaN
# 346923                                                NaN
# 346924                                                NaN
# 346925                   8024 22nd Ave, Kenosha, WI 53143
#
#                                  category            city         country  \
# 0                 Fabric-Based Home Goods         gosford       australia
# 1                             Book Stores  st. catharines          canada
# ...

# %%
df2.merge(df3, on=['domain','name','category','city','region','country','phone'], how='left')
# Out:
#                                                   address  \
# 0       28 Central Coast Hwy, West Gosford NSW 2250, A...
# 1        400 Scott St, St. Catharines, ON L2M 3W2, Canada
# 2           191 Pleasant St, Yarmouth, NS B5A 2J9, Canada
# 3       11040 Santa Monica Blvd Suite 370, Los Angeles...
# 4                                                     NaN
# ...                                                   ...
# 346921  12b Marsh Cl, Winterbourne, Bristol BS36 1HY, ...
# 346922                                                NaN
# 346923                                                NaN
# 346924                                                NaN
# 346925                   8024 22nd Ave, Kenosha, WI 53143
#
#                                  category            city         country  \
# 0                 Fabric-Based Home Goods         gosford       australia
# 1                             Book Stores  st. catharines          canada
# ...

# %%
df2.dropna(inplace=True)

# %%
df2.isnull()
# Out:
#         address  category   city  country   name  phone  region  zip_code  \
# 0         False     False  False    False  False  False   False     False
# 1         False     False  False    False  False  False   False     False
# 2         False     False  False    False  False  False   False     False
# 3         False     False  False    False  False  False   False     False
# 7         False     False  False    False  False  False   False     False
# ...         ...       ...    ...      ...    ...    ...     ...       ...
# 346903    False     False  False    False  False  False   False     False
# 346905    False     False  False    False  False  False   False     False
# 346914    False     False  False    False  False  False   False     False
# 346915    False     False  False    False  False  False   False     False
# 346921    False     False  False    False  False  False   False     False
#
#         domain
# 0        False
# 1        False
# 2        False
# ...

# %%
df2.loc[df2['domain']=='bookmanager.com']
# Out:
#                                                  address  \
# 1       400 Scott St, St. Catharines, ON L2M 3W2, Canada
# 27537        7 Perron St, St. Albert, AB T8N 1E3, Canada
# 53688      262 Piccadilly St, London, ON N6A 1S4, Canada
# 163154      411 Bernard Ave, Kelowna, BC V1Y 6N8, Canada
#
#                              category            city country  \
# 1                         Book Stores  st. catharines  canada
# 27537        Malls & Shopping Centers      st. albert  canada
# 53688                     Book Stores          london  canada
# 163154  Software Development Services         kelowna  canada
#
#                                   name         phone            region  \
# 1        Heritage Christian Book Store  +19059374553           ontario
# 27537   The Bookstore on Perron Street  +17804583155           alberta
# 53688             Oxford Book Shop Ltd  +15194388336           ontario
# 163154                     Bookmanager  +12507634415  british columbia
#
# ...

# %%
df2.nunique()
# Out:
# address     197432
# category       466
# city         16637
# country        123
# name        214979
# phone       196060
# region        1015
# zip_code     86078
# domain       48280
# dtype: int64

# %%
df2_copy = df2.copy()
df2_copy['duplicated'] = df2_copy.duplicated()
df2_copy
# Out:
#                                                   address  \
# 0       28 Central Coast Hwy, West Gosford NSW 2250, A...
# 1        400 Scott St, St. Catharines, ON L2M 3W2, Canada
# 2           191 Pleasant St, Yarmouth, NS B5A 2J9, Canada
# 3       11040 Santa Monica Blvd Suite 370, Los Angeles...
# 7               55 S Cleveland Ave, Westerville, OH 43081
# ...                                                   ...
# 346903  Tenzing Rd, Hemel Hempstead HP2 4HS, United Ki...
# 346905          12 Mechanic St, Paris, ON N3L 1J9, Canada
# 346914                 4536 Vine St, Cincinnati, OH 45217
# 346915  2121 Premier Way UNIT 100, Sherwood Park, AB T...
# 346921  12b Marsh Cl, Winterbourne, Bristol BS36 1HY, ...
#
#                                   category             city         country  \
# 0                  Fabric-Based Home Goods          gosford       australia
# 1                              Book Stores   st. catharines          canada
# ...

# %%
df2_copy.loc[df2_copy['duplicated']==True]
# Out:
# Empty DataFrame
# Columns: [address, category, city, country, name, phone, region, zip_code, domain, duplicated]
# Index: []
